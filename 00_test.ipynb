# %%
name=input("Enter your name: ")

# %%
#create a simple if elif else code to check marks and give grades
#grade A,B,C,D,F based on the marks entered by user


marks = int(input("Enter your marks: "))
if marks >= 80:
    grade = "A"
elif marks >= 60:
    grade = "B"
elif marks >= 40:
    grade = "C"
else:
    grade = "F"
print(f"Your grade is: {grade}")
